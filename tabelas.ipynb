# %%
import pandas as pd

df = pd.read_csv('resultados_experimento_1.csv')

df
# Out:
#                    Algoritmo Funcao_Custo  Funcao_Heuristica  Custo_Caminho  \
# 0           Busca em Largura     custo_c1                NaN             70
# 1      Busca em Profundidade     custo_c1                NaN           1110
# 2    Busca de Custo Uniforme     custo_c1                NaN             70
# 3           Busca em Largura     custo_c2                NaN             80
# 4      Busca em Profundidade     custo_c2                NaN           1130
# ..                       ...          ...                ...            ...
# 595    Busca em Profundidade     custo_c3                NaN           6186
# 596  Busca de Custo Uniforme     custo_c3                NaN            313
# 597         Busca em Largura     custo_c4                NaN            265
# 598    Busca em Profundidade     custo_c4                NaN           6130
# 599  Busca de Custo Uniforme     custo_c4                NaN            265
#
#      Nos_Gerados  Nos_Visitados  \
# ...

# %%
df = pd.read_csv('resultados_experimento_2.csv')

df
# Out:
#                    Algoritmo Funcao_Custo      Funcao_Heuristica  \
# 0    Busca de Custo Uniforme     custo_c1                    NaN
# 1                   Busca A*     custo_c1  heuristica_euclidiana
# 2                   Busca A*     custo_c1   heuristica_manhattan
# 3    Busca de Custo Uniforme     custo_c2                    NaN
# 4                   Busca A*     custo_c2  heuristica_euclidiana
# ..                       ...          ...                    ...
# 595                 Busca A*     custo_c3  heuristica_euclidiana
# 596                 Busca A*     custo_c3   heuristica_manhattan
# 597  Busca de Custo Uniforme     custo_c4                    NaN
# 598                 Busca A*     custo_c4  heuristica_euclidiana
# 599                 Busca A*     custo_c4   heuristica_manhattan
#
#      Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0              370         1741           1710
# 1              370          822            754
# ...

# %%
df = pd.read_csv('resultados_experimento_3.csv')

df
# Out:
#         Algoritmo Funcao_Custo      Funcao_Heuristica  Custo_Caminho  \
# 0    Busca Gulosa     custo_c1  heuristica_euclidiana            150
# 1    Busca Gulosa     custo_c2  heuristica_euclidiana            205
# 2    Busca Gulosa     custo_c3  heuristica_euclidiana            177
# 3    Busca Gulosa     custo_c4  heuristica_euclidiana            145
# 4        Busca A*     custo_c1  heuristica_euclidiana            150
# ..            ...          ...                    ...            ...
# 795  Busca Gulosa     custo_c4   heuristica_manhattan            293
# 796      Busca A*     custo_c1   heuristica_manhattan            290
# 797      Busca A*     custo_c2   heuristica_manhattan            320
# 798      Busca A*     custo_c3   heuristica_manhattan            308
# 799      Busca A*     custo_c4   heuristica_manhattan            256
#
#      Nos_Gerados  Nos_Visitados  \
# 0             46             16
# 1             46             16
# 2             46             16
# ...

# %%
df = pd.read_csv('resultados_experimento_4.csv')

df
# Out:
#                            Algoritmo Funcao_Custo  Funcao_Heuristica  \
# 0          Busca em Largura (Random)     custo_c1                NaN
# 1     Busca em Profundidade (Random)     custo_c1                NaN
# 2          Busca em Largura (Random)     custo_c2                NaN
# 3     Busca em Profundidade (Random)     custo_c2                NaN
# 4          Busca em Largura (Random)     custo_c3                NaN
# ...                              ...          ...                ...
# 1595  Busca em Profundidade (Random)     custo_c2                NaN
# 1596       Busca em Largura (Random)     custo_c3                NaN
# 1597  Busca em Profundidade (Random)     custo_c3                NaN
# 1598       Busca em Largura (Random)     custo_c4                NaN
# 1599  Busca em Profundidade (Random)     custo_c4                NaN
#
#       Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0               250          885            866
# ...

# %%
df = pd.read_csv('resultados_experimento_5.csv')

df
# Out:
#                Algoritmo Funcao_Custo      Funcao_Heuristica  Custo_Caminho  \
# 0    Busca A* (Farmacia)     custo_c1  heuristica_euclidiana            350
# 1    Busca A* (Farmacia)     custo_c1   heuristica_manhattan            350
# 2    Busca A* (Farmacia)     custo_c2  heuristica_euclidiana            435
# 3    Busca A* (Farmacia)     custo_c2   heuristica_manhattan            455
# 4    Busca A* (Farmacia)     custo_c3  heuristica_euclidiana            388
# ..                   ...          ...                    ...            ...
# 195  Busca A* (Farmacia)     custo_c2   heuristica_manhattan            480
# 196  Busca A* (Farmacia)     custo_c3  heuristica_euclidiana            406
# 197  Busca A* (Farmacia)     custo_c3   heuristica_manhattan            405
# 198  Busca A* (Farmacia)     custo_c4  heuristica_euclidiana            322
# 199  Busca A* (Farmacia)     custo_c4   heuristica_manhattan            325
#
#      Nos_Gerados  Nos_Visitados  \
# ...
