# %%
import pandas as pd

df = pd.read_csv('resultados_experimento_1.csv')

df
# Out:
#     No_Inicial  No_Final                Algoritmo Funcao_Custo  \
# 0     (21, 16)  (20, 11)         Busca em Largura     custo_c1
# 1     (21, 16)  (20, 11)    Busca em Profundidade     custo_c1
# 2     (21, 16)  (20, 11)  Busca de Custo Uniforme     custo_c1
# 3     (21, 16)  (20, 11)         Busca em Largura     custo_c2
# 4     (21, 16)  (20, 11)    Busca em Profundidade     custo_c2
# ..         ...       ...                      ...          ...
# 595    (0, 19)   (15, 0)    Busca em Profundidade     custo_c3
# 596    (0, 19)   (15, 0)  Busca de Custo Uniforme     custo_c3
# 597    (0, 19)   (15, 0)         Busca em Largura     custo_c4
# 598    (0, 19)   (15, 0)    Busca em Profundidade     custo_c4
# 599    (0, 19)   (15, 0)  Busca de Custo Uniforme     custo_c4
#
#      Funcao_Heuristica  Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0                  NaN             60           95             71
# 1                  NaN           1200          729            579
# 2                  NaN             60          163            119
# 3                  NaN             65           95             71
# 4                  NaN           1225          729            579
# ..                 ...            ...          ...            ...
# 595                NaN           4801          957            477
# 596                NaN            373         1444           1389
# 597                NaN            325          834            813
# 598                NaN           4765          957            477
# 599                NaN            333         1516           1447
#
#                                     Caminho_Encontrado  Farmacias
# 0    [(21, 16), (20, 16), (20, 15), (20, 14), (20, ...        NaN
# 1    [(21, 16), (21, 17), (21, 18), (21, 19), (21, ...        NaN
# 2    [(21, 16), (21, 15), (21, 14), (21, 13), (21, ...        NaN
# 3    [(21, 16), (20, 16), (20, 15), (20, 14), (20, ...        NaN
# 4    [(21, 16), (21, 17), (21, 18), (21, 19), (21, ...        NaN
# ..                                                 ...        ...
# 595  [(0, 19), (0, 20), (0, 21), (0, 22), (0, 23), ...        NaN
# 596  [(0, 19), (1, 19), (2, 19), (3, 19), (4, 19), ...        NaN
# 597  [(0, 19), (1, 19), (2, 19), (3, 19), (4, 19), ...        NaN
# 598  [(0, 19), (0, 20), (0, 21), (0, 22), (0, 23), ...        NaN
# 599  [(0, 19), (0, 18), (0, 17), (0, 16), (0, 15), ...        NaN
#
# [600 rows x 10 columns]

# %%
df = pd.read_csv('resultados_experimento_2.csv')

df
# Out:
#     No_Inicial  No_Final                Algoritmo Funcao_Custo  \
# 0       (5, 4)   (4, 29)  Busca de Custo Uniforme     custo_c1
# 1       (5, 4)   (4, 29)                 Busca A*     custo_c1
# 2       (5, 4)   (4, 29)                 Busca A*     custo_c1
# 3       (5, 4)   (4, 29)  Busca de Custo Uniforme     custo_c2
# 4       (5, 4)   (4, 29)                 Busca A*     custo_c2
# ..         ...       ...                      ...          ...
# 595   (24, 15)  (21, 10)                 Busca A*     custo_c3
# 596   (24, 15)  (21, 10)                 Busca A*     custo_c3
# 597   (24, 15)  (21, 10)  Busca de Custo Uniforme     custo_c4
# 598   (24, 15)  (21, 10)                 Busca A*     custo_c4
# 599   (24, 15)  (21, 10)                 Busca A*     custo_c4
#
#          Funcao_Heuristica  Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0                      NaN            260         1175           1109
# 1    heuristica_euclidiana            260          127             75
# 2     heuristica_manhattan            260           79             27
# 3                      NaN            265          909            848
# 4    heuristica_euclidiana            390          130             52
# ..                     ...            ...          ...            ...
# 595  heuristica_euclidiana             86           55             31
# 596   heuristica_manhattan             86           38             16
# 597                    NaN             74          251            190
# 598  heuristica_euclidiana             74           36             16
# 599   heuristica_manhattan             74           25              9
#
#                                     Caminho_Encontrado  Farmacias
# 0    [(5, 4), (5, 5), (5, 6), (5, 7), (5, 8), (5, 9...        NaN
# 1    [(5, 4), (4, 4), (4, 5), (4, 6), (4, 7), (4, 8...        NaN
# 2    [(5, 4), (4, 4), (4, 5), (4, 6), (4, 7), (4, 8...        NaN
# 3    [(5, 4), (4, 4), (4, 5), (4, 6), (4, 7), (4, 8...        NaN
# 4    [(5, 4), (4, 4), (4, 5), (4, 6), (4, 7), (4, 8...        NaN
# ..                                                 ...        ...
# 595  [(24, 15), (24, 14), (24, 13), (24, 12), (24, ...        NaN
# 596  [(24, 15), (24, 14), (24, 13), (24, 12), (24, ...        NaN
# 597  [(24, 15), (24, 14), (24, 13), (24, 12), (24, ...        NaN
# 598  [(24, 15), (24, 14), (24, 13), (24, 12), (24, ...        NaN
# 599  [(24, 15), (24, 14), (24, 13), (24, 12), (24, ...        NaN
#
# [600 rows x 10 columns]

# %%
df = pd.read_csv('resultados_experimento_3.csv')

df
# Out:
#     No_Inicial  No_Final     Algoritmo Funcao_Custo      Funcao_Heuristica  \
# 0     (18, 15)  (18, 10)  Busca Gulosa     custo_c1  heuristica_euclidiana
# 1     (18, 15)  (18, 10)  Busca Gulosa     custo_c2  heuristica_euclidiana
# 2     (18, 15)  (18, 10)  Busca Gulosa     custo_c3  heuristica_euclidiana
# 3     (18, 15)  (18, 10)  Busca Gulosa     custo_c4  heuristica_euclidiana
# 4     (18, 15)  (18, 10)      Busca A*     custo_c1  heuristica_euclidiana
# ..         ...       ...           ...          ...                    ...
# 795     (9, 5)  (20, 25)  Busca Gulosa     custo_c4   heuristica_manhattan
# 796     (9, 5)  (20, 25)      Busca A*     custo_c1   heuristica_manhattan
# 797     (9, 5)  (20, 25)      Busca A*     custo_c2   heuristica_manhattan
# 798     (9, 5)  (20, 25)      Busca A*     custo_c3   heuristica_manhattan
# 799     (9, 5)  (20, 25)      Busca A*     custo_c4   heuristica_manhattan
#
#      Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0               50           16              6
# 1               50           16              6
# 2               50           16              6
# 3               50           16              6
# 4               50           16              6
# ..             ...          ...            ...
# 795            310           94             32
# 796            310          535            471
# 797            390          644            497
# 798            335          508            310
# 799            285          126             55
#
#                                     Caminho_Encontrado  Farmacias
# 0    [(18, 15), (18, 14), (18, 13), (18, 12), (18, ...        NaN
# 1    [(18, 15), (18, 14), (18, 13), (18, 12), (18, ...        NaN
# 2    [(18, 15), (18, 14), (18, 13), (18, 12), (18, ...        NaN
# 3    [(18, 15), (18, 14), (18, 13), (18, 12), (18, ...        NaN
# 4    [(18, 15), (18, 14), (18, 13), (18, 12), (18, ...        NaN
# ..                                                 ...        ...
# 795  [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 1...        NaN
# 796  [(9, 5), (10, 5), (11, 5), (12, 5), (13, 5), (...        NaN
# 797  [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 1...        NaN
# 798  [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 1...        NaN
# 799  [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 1...        NaN
#
# [800 rows x 10 columns]

# %%
df = pd.read_csv('resultados_experimento_4.csv')

df
# Out:
#      No_Inicial No_Final                       Algoritmo Funcao_Custo  \
# 0      (18, 24)  (8, 17)       Busca em Largura (Random)     custo_c1
# 1      (18, 24)  (8, 17)  Busca em Profundidade (Random)     custo_c1
# 2      (18, 24)  (8, 17)       Busca em Largura (Random)     custo_c2
# 3      (18, 24)  (8, 17)  Busca em Profundidade (Random)     custo_c2
# 4      (18, 24)  (8, 17)       Busca em Largura (Random)     custo_c3
# ...         ...      ...                             ...          ...
# 1595   (29, 12)  (2, 14)  Busca em Profundidade (Random)     custo_c2
# 1596   (29, 12)  (2, 14)       Busca em Largura (Random)     custo_c3
# 1597   (29, 12)  (2, 14)  Busca em Profundidade (Random)     custo_c3
# 1598   (29, 12)  (2, 14)       Busca em Largura (Random)     custo_c4
# 1599   (29, 12)  (2, 14)  Busca em Profundidade (Random)     custo_c4
#
#       Funcao_Heuristica  Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0                   NaN            170          475            438
# 1                   NaN           2130          570            224
# 2                   NaN            220          482            445
# 3                   NaN           5500         1150            521
# 4                   NaN            195          468            431
# ...                 ...            ...          ...            ...
# 1595                NaN           4775         1455            893
# 1596                NaN            354          727            698
# 1597                NaN           2612          767            418
# 1598                NaN            274          727            698
# 1599                NaN           4473         1621            973
#
#                                      Caminho_Encontrado  Farmacias
# 0     [(18, 24), (17, 24), (17, 23), (16, 23), (16, ...        NaN
# 1     [(18, 24), (17, 24), (17, 23), (16, 23), (15, ...        NaN
# 2     [(18, 24), (18, 23), (17, 23), (17, 22), (16, ...        NaN
# 3     [(18, 24), (17, 24), (17, 25), (17, 26), (18, ...        NaN
# 4     [(18, 24), (17, 24), (16, 24), (16, 23), (16, ...        NaN
# ...                                                 ...        ...
# 1595  [(29, 12), (30, 12), (30, 11), (30, 10), (29, ...        NaN
# 1596  [(29, 12), (29, 13), (28, 13), (28, 14), (27, ...        NaN
# 1597  [(29, 12), (30, 12), (30, 13), (29, 13), (28, ...        NaN
# 1598  [(29, 12), (29, 13), (29, 14), (28, 14), (27, ...        NaN
# 1599  [(29, 12), (29, 13), (30, 13), (30, 12), (30, ...        NaN
#
# [1600 rows x 10 columns]

# %%
df = pd.read_csv('resultados_experimento_5.csv')

df
# Out:
#     No_Inicial  No_Final            Algoritmo Funcao_Custo  \
# 0     (19, 20)  (10, 23)  Busca A* (Farmacia)     custo_c1
# 1     (19, 20)  (10, 23)  Busca A* (Farmacia)     custo_c1
# 2     (19, 20)  (10, 23)  Busca A* (Farmacia)     custo_c2
# 3     (19, 20)  (10, 23)  Busca A* (Farmacia)     custo_c2
# 4     (19, 20)  (10, 23)  Busca A* (Farmacia)     custo_c3
# ..         ...       ...                  ...          ...
# 195    (9, 17)   (20, 7)  Busca A* (Farmacia)     custo_c2
# 196    (9, 17)   (20, 7)  Busca A* (Farmacia)     custo_c3
# 197    (9, 17)   (20, 7)  Busca A* (Farmacia)     custo_c3
# 198    (9, 17)   (20, 7)  Busca A* (Farmacia)     custo_c4
# 199    (9, 17)   (20, 7)  Busca A* (Farmacia)     custo_c4
#
#          Funcao_Heuristica  Custo_Caminho  Nos_Gerados  Nos_Visitados  \
# 0    heuristica_euclidiana            160          129             91
# 1     heuristica_manhattan            160           50             18
# 2    heuristica_euclidiana            205          220            156
# 3     heuristica_manhattan            205          156            108
# 4    heuristica_euclidiana            178          179            120
# ..                     ...            ...          ...            ...
# 195   heuristica_manhattan            345          345            160
# 196  heuristica_euclidiana            319          499            399
# 197   heuristica_manhattan            317          296            144
# 198  heuristica_euclidiana            285          315            214
# 199   heuristica_manhattan            301          122             53
#
#                                     Caminho_Encontrado  \
# 0    [(19, 20), (19, 19), (18, 19), (17, 19), (17, ...
# 1    [(19, 20), (18, 20), (17, 20), (17, 19), (17, ...
# 2    [(19, 20), (19, 19), (19, 18), (18, 18), (17, ...
# 3    [(19, 20), (19, 19), (19, 18), (18, 18), (17, ...
# 4    [(19, 20), (18, 20), (18, 19), (17, 19), (17, ...
# ..                                                 ...
# 195  [(9, 17), (10, 17), (10, 18), (10, 19), (10, 2...
# 196  [(9, 17), (9, 18), (9, 19), (9, 20), (9, 21), ...
# 197  [(9, 17), (9, 18), (9, 19), (9, 20), (9, 21), ...
# 198  [(9, 17), (9, 18), (9, 19), (9, 20), (9, 21), ...
# 199  [(9, 17), (9, 18), (9, 19), (9, 20), (9, 21), ...
#
#                                  Farmacias
# 0      [(4, 5), (3, 1), (17, 18), (4, 14)]
# 1      [(4, 5), (3, 1), (17, 18), (4, 14)]
# 2      [(4, 5), (3, 1), (17, 18), (4, 14)]
# 3      [(4, 5), (3, 1), (17, 18), (4, 14)]
# 4      [(4, 5), (3, 1), (17, 18), (4, 14)]
# ..                                     ...
# 195  [(28, 2), (25, 7), (10, 21), (0, 22)]
# 196  [(28, 2), (25, 7), (10, 21), (0, 22)]
# 197  [(28, 2), (25, 7), (10, 21), (0, 22)]
# 198  [(28, 2), (25, 7), (10, 21), (0, 22)]
# 199  [(28, 2), (25, 7), (10, 21), (0, 22)]
#
# [200 rows x 10 columns]
